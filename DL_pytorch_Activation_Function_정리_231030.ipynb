# %% [markdown]
# <a href="https://colab.research.google.com/github/eunzzae/Study_DL/blob/main/DL_pytorch_Activation_Function_%EC%A0%95%EB%A6%AC_231030.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Activation Function
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 시그모이드 함수의 또 다른 문제점은 원점 중심이 아니라는 점입니다(Not zero-centered). 따라서, 평균이 0이 아니라 0.5이며, 시그모이드 함수는 항상 양수를 출력하기 때문에 출력의 가중치 합이 입력의 가중치 합보다 커질 가능성이 높습니다. 이것을 편향 이동(bias shift)이라 하며, 이러한 이유로 각 레이어를 지날 때마다 분산이 계속 커져 가장 높은 레이어에서는 활성화 함수의 출력이 0이나 1로 수렴하게 되어 기울기 소실 문제가 일어날 수 있습니다.
#
# * 하이퍼볼릭탄젠트 함수는 원점 중심(zero-centered)이기 때문에, 시그모이드와 달리 편향 이동은 일어나지 않습니다. 하지만, 하이퍼볼릭탄젠트 함수 또한 입력의 절대값이 클 경우 -1이나 1로 수렴하게 되는데 시그모이드 함수와 마찬가지로 이때 기울기가 완만해지므로 역시나 기울기 소실 문제가 일어날 수 있습니다.
#
# * 스탠포드 대학교의 딥 러닝 강의 cs231n에서는 ReLU를 먼저 시도해보고, 그다음으로 LeakyReLU나 ELU 같은 ReLU의 변형들을 시도해보며, sigmoid는 사용하지 말라고 권장합니다.

# %%
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# ## ReLU 함수
# * ReLU(x) = max(x, 0) 그래프

# %%
def relu(x):
    return np.maximum(0, x)

x = np.arange(-5.0, 5.0, 0.1)
y = relu(x)

plt.plot(x, y)
plt.plot([0,0], [5.0, 0.0], ':')
plt.title('Relu Function')
plt.show()

# %% [markdown]
# ## Leaky ReLU 함수 그래프

# %%
def leaky_relu(x):
    return np.maximum(0.1*x, x)

x = np.arange(-5.0, 5.0, 0.1)
y = leaky_relu(x)

plt.plot(x, y)
plt.plot([0,0], [5.0, 0.0], ':')
plt.title('Leaky ReLU Function')
plt.show()

# %% [markdown]
# ## sigmoid 함수 그래프

# %%
def sigmoid(x):
  return 1/ (1 + np.exp(-x))

array = np.arange(-10, 10, 0.1)
plt.axvline(x=0, color='g', linestyle='--', linewidth=1)
plt.axhline(y=0, color='g', linestyle='--', linewidth=1)
plt.plot(array, sigmoid(array))
plt.show()

# %% [markdown]
# ## tanh 함수 그래프
# * tanh(x) 함수는 (ex - e-x) / (ex + e-x)
# = (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))
# = np.sinh(x) / np.cosh(x) 와 동일합니다.

# %%
# x = np.linspace(-np.pi, np.pi, 201)
x = np.linspace(-4, 4, 1000)
plt.plot(x, np.tanh(x))
plt.axvline(x=0, color='r', linestyle='--', linewidth=1)
plt.axhline(y=0, color='r', linestyle='--', linewidth=1)
plt.xlabel('x')
plt.ylabel('tanh(x)')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Output Function

# %% [markdown]
# ## Softmax 함수
# * output을 정규화하여 가중 합계 값에서 합이 1이되는 확률로 변환
# * output의 각 값은 각 클래스의 소속 확률로 해석됨
#
# cf)
# * linear(선형) 및 sigmoid(시그모이드) activation function은 multi-class classification에 적합하지 않음
# * softmax는 목록에서 가장 큰 값의 인덱스를 반환하는 argmax 함수의 완화 버전

# %% [markdown]
# ## Softmax 함수 그래프
# * 시그모이드 함수는 두 가지 선택지 중 하나를 고르는 이진분류(binary classification) 문제에 사용
# * 세 가지 이상(상호 배타적인) 선택지 중 하나를 고르는 다중 클래스 분류(MultiClas Classification) 문제에 주로 사용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = np.arange(-5.0, 5.0, 0.1) # -5.0부터 5.0까지 0.1 간격 생성
y = np.exp(x) / np.sum(np.exp(x))

plt.plot(x, y)
plt.title('Softmax Function')
plt.show()
